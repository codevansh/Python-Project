# %% [markdown]
# <a href="https://colab.research.google.com/github/codevansh/Python-Project/blob/main/learning-data-science--5/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# steps to model a problem as a ml problem:
# 1. look at the bigger picture (why to use ml ?? what would it help in??)
# 2. get the data
# 3. explore and visualize the data
# 4. prepare the data
# 5. select a model and train it
# 6. fine tune your model
# 7. present and launch the model

# %% [markdown]
# questions::
# 1. which tyoe of problem it is?
# --> supervised ,unsupervised or reinforcement??
# 2. is it ?? --> classification or regression
#
#
# answer --> it is supervised (as it has labeled data) and regression data.
